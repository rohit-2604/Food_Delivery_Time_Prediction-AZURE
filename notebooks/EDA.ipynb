# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"D:\Final_year\Final_year_MCA_project\Food_Delivery_Time_Prediction-AZURE\notebooks\cleaned_data.csv")

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# 2                    74.006619                   4                     3
#
#    Vehicle_condition  Type_of_vehicle  ...  City  Time_taken(min)  \
# 0                  2                1  ...     2               46
# ...

# %% [markdown]
# ## Removing unnecessary columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42646 entries, 0 to 42645
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          42646 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          42646 non-null  float64
#  3   Restaurant_longitude         42646 non-null  float64
#  4   Delivery_location_latitude   42646 non-null  float64
#  5   Delivery_location_longitude  42646 non-null  float64
#  6   Weather_conditions           42646 non-null  int64
#  7   Road_traffic_density         42646 non-null  int64
#  8   Vehicle_condition            42646 non-null  int64
#  9   Type_of_vehicle              42646 non-null  int64
#  10  multiple_deliveries          42646 non-null  float64
#  11  City                         42646 non-null  int64
#  12  Time_taken(min)              42646 non-null  int64
# ...

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# 2                    74.006619                   4                     3
#
#    Vehicle_condition  Type_of_vehicle  ...  City  Time_taken(min)  \
# 0                  2                1  ...     2               46
# ...

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %% [markdown]
# Dropped Time_Orderd and Time_Order_picked as they wont be taking as much part in affecting delivery time (neutral correlation) as we have other factors which would help us determine delivery time better.

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# 2                    74.006619                   4                     3
#
#    Vehicle_condition  Type_of_vehicle  ...  City  Time_taken(min)  \
# 0                  2                1  ...     2               46
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42646 entries, 0 to 42645
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          42646 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          42646 non-null  float64
#  3   Restaurant_longitude         42646 non-null  float64
#  4   Delivery_location_latitude   42646 non-null  float64
#  5   Delivery_location_longitude  42646 non-null  float64
#  6   Weather_conditions           42646 non-null  int64
#  7   Road_traffic_density         42646 non-null  int64
#  8   Vehicle_condition            42646 non-null  int64
#  9   Type_of_vehicle              42646 non-null  int64
#  10  multiple_deliveries          42646 non-null  float64
#  11  City                         42646 non-null  int64
#  12  Time_taken(min)              42646 non-null  int64
# ...

# %% [markdown]
# ## Determining Column Types:

# %%
data.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %% [markdown]
# 1. Delivery_person_Age: Numerical/Quantitative Data - Continuous data.<br>
#
# 2. Delivery_person_Ratings: Numerical/Quantitative Data - Continuous data.<br>
#
# 3. Restaurant_latitude: Numerical/Quantitative Data - Continuous data.<br>
#
# 4. Restaurant_longitude: Numerical/Quantitative Data - Continuous data.<br>
#
# 5. Delivery_location_latitude: Numerical/Quantitative Data - Continuous data.<br>
#
# 6. Delivery_location_longitude: Numerical/Quantitative Data - Continuous data.<br>
#
# 7. Order_Date: Date Time.<br>
#
# 8. Weather_conditions: Categorical/Qualitative Data - Ordinal.<br>
#
# 9. Road_traffic_density: Categorical/Qualitative Data - Ordinal.<br>
#
# 10. Vehicle_condition: Categorical/Qualitative Data - Ordinal.<br>
#
# 11. Type_of_order: Categorical/Qualitative Data - Nominal.<br>
#
# 12. Type_of_vehicle: Categorical/Qualitative Data - Nominal.<br>
#
# 13. multiple_deliveries: Numerical/Quantitative Data - Ratio Scale Data.<br>
#
# 14. Festival: Categorical/Qualitative Data - Nominal.<br>
#
# 15. City: Categorical/Qualitative Data - Ordinal.<br>
#
# 16. Time_taken (min): Numerical/Quantitative Data - Continuous data.<br>

# %% [markdown]
# ## Checking for Null Values:

# %%
with_nan = data.shape

# %%
data.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings        1287
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_vehicle                   0
# multiple_deliveries               0
# City                              0
# Time_taken(min)                   0
# Day_Ordered                       0
# Month_Ordered                     0
# Year_Ordered                      0
# Type_of_order_Buffet              0
# Type_of_order_Drinks              0
# Type_of_order_Meal                0
# Type_of_order_Snack               0
# Festival_Yes                      0
# dtype: int64

# %% [markdown]
# - Delivery_person_Age<br>
# - Delivery_person_Ratings<br>
# - Weather_conditions <br>
# - Road_traffic_density<br>
# - multiple_deliveries<br>
# - Festival<br>
# - City<br>

# %%
import pandas as pd

def mode_counter(data, column_name):
    modes = df[column_name].mode()

    if len(modes) > 1:
        print("There are multiple mode values in the column.")
        return modes  # Handle multiple modes as needed
    else:
        print("There is a single mode value in the column.")
        return modes[0]  # Return the single mode value

# %%
data.dropna(subset=["multiple_deliveries"], inplace=True)

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# 2                    74.006619                   4                     3
#
#    Vehicle_condition  Type_of_vehicle  ...  City  Time_taken(min)  \
# 0                  2                1  ...     2               46
# ...

# %% [markdown]
# Verifying function's functionality

# %%
df = pd.DataFrame({
    "Delivery_person_Ratings": [5,5,6,8,3,2,4,5,8,2,2]
})

# %%
mode_counter(df,"Delivery_person_Ratings")
# Out:
# There are multiple mode values in the column.
# 0    2
# 1    5
# Name: Delivery_person_Ratings, dtype: int64

# %%
mode_ratings = mode_counter(data,"Delivery_person_Ratings")
# Out:
# There are multiple mode values in the column.

# %%
mode_ratings
# Out:
# 0    2
# 1    5
# Name: Delivery_person_Ratings, dtype: int64

# %%
data["Delivery_person_Ratings"] = data["Delivery_person_Ratings"].fillna(mode_ratings)

# %%
data.dropna(subset=["Weather_conditions"], inplace=True)

# %%
data["Road_traffic_density"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()  # Removes any leading/trailing spaces

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %%
data.dropna(subset=["Festival_Yes"], inplace=True)

# %%
data.dropna(subset=["City"], inplace=True)

# %%
data.isnull().sum()
# Out:
# Delivery_person_Age               0
# Delivery_person_Ratings        1287
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Weather_conditions                0
# Road_traffic_density              0
# Vehicle_condition                 0
# Type_of_vehicle                   0
# multiple_deliveries               0
# City                              0
# Time_taken(min)                   0
# Day_Ordered                       0
# Month_Ordered                     0
# Year_Ordered                      0
# Type_of_order_Buffet              0
# Type_of_order_Drinks              0
# Type_of_order_Meal                0
# Type_of_order_Snack               0
# Festival_Yes                      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42646 entries, 0 to 42645
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          42646 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          42646 non-null  float64
#  3   Restaurant_longitude         42646 non-null  float64
#  4   Delivery_location_latitude   42646 non-null  float64
#  5   Delivery_location_longitude  42646 non-null  float64
#  6   Weather_conditions           42646 non-null  int64
#  7   Road_traffic_density         42646 non-null  int64
#  8   Vehicle_condition            42646 non-null  int64
#  9   Type_of_vehicle              42646 non-null  int64
#  10  multiple_deliveries          42646 non-null  float64
#  11  City                         42646 non-null  int64
#  12  Time_taken(min)              42646 non-null  int64
# ...

# %% [markdown]
# ## Checking for outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def histplotcount_func(input_feature,data,no_of_bins):
    """This function wil plot a histogram based on given arguments with y-axis=Frequency"""
    plt.figure(figsize=(10,6))
    sns.histplot(data[input_feature], bins=no_of_bins, kde=True)
    plt.title(f"Distribution of {input_feature}")
    plt.xlabel(f"{input_feature}")
    plt.ylabel("Frequency")
    plt.show()

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the function
def histplotcount_func(column_name, data, bins):
    # Check if the column exists in the dataframe
    if column_name in data.columns:
        plt.figure(figsize=(8, 6))  # Optional: adjust the figure size
        sns.histplot(data[column_name], bins=bins, kde=True)
        plt.title(f"Distribution of {column_name}")
        plt.xlabel(column_name)
        plt.ylabel("Frequency")
        plt.show()
    else:
        print(f"Column '{column_name}' not found in the DataFrame.")

# %%
histplotcount_func("Delivery_person_Age", data, 5)

# %%
print(data.head())
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# ...

# %% [markdown]
# As we can see its a normal distribution which means no outliers in Delivery_person_Age column so we use mean instead of median.

# %%
mean_age = data["Delivery_person_Age"].mean()
data["Delivery_person_Age"] = data["Delivery_person_Age"].fillna(mean_age)

# %%
data["Delivery_person_Ratings"].value_counts()
# Out:
# Delivery_person_Ratings
# 4.8    6748
# 4.7    6740
# 4.9    6663
# 4.6    6566
# 5.0    3789
# 4.5    3101
# 4.1    1383
# 4.2    1377
# 4.3    1364
# 4.4    1304
# 4.0    1034
# 3.5     241
# 3.8     223
# 3.7     218
# 3.6     201
# 3.9     191
# 3.4      31
# 3.2      29
# 3.1      26
# 3.3      25
# 2.6      21
# 2.7      21
# 2.5      20
# 2.8      19
# 2.9      19
# 3.0       5
# Name: count, dtype: int64

# %% [markdown]
# as we can see we have record where rating = 6 [outlier]

# %%
data = data.drop(data[data["Delivery_person_Ratings"] == 6.0].index)

# %% [markdown]
# We dropped them as they were only 53/45584 (0.11%)

# %%
histplotcount_func("Delivery_person_Ratings",data,5)

# %%
import pandas as pd
# Loop through each column in the DataFrame
for i in data.columns:
    print(f"Column Name: {i}, Column Type: {data[i].dtype}")
    print("="*64)
    unique_values = data[i].unique()
    print(unique_values)
    print("="*64)
# Out:
# Column Name: Delivery_person_Age, Column Type: float64
# ...
# [36.         21.         23.         34.         24.         29.
#  35.         33.         25.         31.         37.         27.
#  32.         26.         38.         20.         22.         29.60915238
#  28.         39.         30.        ]
# ...
# Column Name: Delivery_person_Ratings, Column Type: float64
# ...
# [4.2 4.7 4.3 4.5 4.  4.1 5.  4.8 4.9 3.5 4.6 nan 4.4 3.8 3.9 3.7 2.6 2.5
#  3.6 3.1 2.7 3.2 3.3 3.4 2.8 2.9 3. ]
# ...
# Column Name: Restaurant_latitude, Column Type: float64
# ...
# [ 30.327968  10.003064  18.56245   30.899584  26.463504  19.176269
#   12.311072  18.592718  22.552672  18.563934  23.357804  11.003669
#   12.986047  19.221315  13.005801  26.849596  21.160522  12.934179
#   18.51421   11.022477  21.160437  15.51315   15.561295   0.
#   18.55144   18.593481  21.173343  17.451976  12.972532  13.064181
#   19.121999  21.149569  19.091458  22.539129  12.970324  21.175975
# ...

# %% [markdown]
# ### location_latitude + longitude

# %%
count_zero_longitude = (data['Delivery_location_latitude'] == "0").sum()
print(f"Number of records with Delivery_location_latitude equal to 0 = {count_zero_longitude}")
# Out:
# Number of records with Delivery_location_latitude equal to 0 = 0

# %%
count_zero_latitude = (data['Restaurant_latitude'] == 0).sum()
print(f"Number of records with Restaurant_latitude equal to 0 = {count_zero_latitude}")
# Out:
# Number of records with Restaurant_latitude equal to 0 = 3410

# %%
count_zero_latitude = (data['Restaurant_latitude'] == 0).sum()
print(f"Number of records with Restaurant_latitude equal to 0 = {count_zero_latitude}")
# Out:
# Number of records with Restaurant_latitude equal to 0 = 3410

# %%
count_zero_longitude = (data['Restaurant_longitude'] == 0).sum()
print(f"Number of records with Restaurant_longitude equal to 0 = {count_zero_longitude}")
# Out:
# Number of records with Restaurant_longitude equal to 0 = 3410

# %%
histplotcount_func("Restaurant_latitude",data,5)

# %%
histplotcount_func("Restaurant_longitude",data,5)

# %%
median_Delivery_location_longitude = data['Delivery_location_longitude'].median()
data["Delivery_location_longitude"] = data["Delivery_location_longitude"].fillna(median_Delivery_location_longitude)

# %%
median_Delivery_location_latitude = data['Delivery_location_latitude'].median()
data["Delivery_location_latitude"] = data["Delivery_location_latitude"].fillna(median_Delivery_location_latitude)

# %% [markdown]
# ### Checking duplicated values

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_vehicle, multiple_deliveries, City, Time_taken(min), Day_Ordered, Month_Ordered, Year_Ordered, Type_of_order_Buffet, Type_of_order_Drinks, Type_of_order_Meal, Type_of_order_Snack, Festival_Yes]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Calculating dataloss

# %%
without_nan = data.shape

# %%
with_nan[0]
# Out:
# 42646

# %%
without_nan[0]
# Out:
# 42646

# %%
with_nan[0]-without_nan[0]
# Out:
# 0

# %%
2938/42646*100
# Out:
# 6.889274492332223

# %% [markdown]
# We have lost only 6.88% values after cleaning data (dropping nan and outlier records)

# %% [markdown]
# ## Correcting Column Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42646 entries, 0 to 42645
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          42646 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          42646 non-null  float64
#  3   Restaurant_longitude         42646 non-null  float64
#  4   Delivery_location_latitude   42646 non-null  float64
#  5   Delivery_location_longitude  42646 non-null  float64
#  6   Weather_conditions           42646 non-null  int64
#  7   Road_traffic_density         42646 non-null  int64
#  8   Vehicle_condition            42646 non-null  int64
#  9   Type_of_vehicle              42646 non-null  int64
#  10  multiple_deliveries          42646 non-null  float64
#  11  City                         42646 non-null  int64
#  12  Time_taken(min)              42646 non-null  int64
# ...

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes'],
#       dtype='object')

# %%
# Create a new column by combining 'Year_Ordered', 'Month_Ordered', and 'Day_Ordered'
data['Order_Date'] = pd.to_datetime(data['Year_Ordered'].astype(str) + '-' + 
                                     data['Month_Ordered'].astype(str) + '-' + 
                                     data['Day_Ordered'].astype(str))

# Check the result
print(data[['Order_Date']].head())
# Out:
#   Order_Date
# 0 2022-02-12
# 1 2022-02-13
# 2 2022-03-04
# 3 2022-02-13
# 4 2022-02-14

# %% [markdown]
# ###  object -> datetime64[ns] (Order_Date)

# %%
data[['Order_Date']].head()
# Out:
#   Order_Date
# 0 2022-02-12
# 1 2022-02-13
# 2 2022-03-04
# 3 2022-02-13
# 4 2022-02-14

# %%
data['Order_Date'].unique()
# Out:
# <DatetimeArray>
# ['2022-02-12 00:00:00', '2022-02-13 00:00:00', '2022-03-04 00:00:00',
#  '2022-02-14 00:00:00', '2022-04-02 00:00:00', '2022-03-01 00:00:00',
#  '2022-03-16 00:00:00', '2022-02-15 00:00:00', '2022-03-10 00:00:00',
#  '2022-03-11 00:00:00', '2022-03-27 00:00:00', '2022-03-26 00:00:00',
#  '2022-04-05 00:00:00', '2022-03-12 00:00:00', '2022-04-01 00:00:00',
#  '2022-03-05 00:00:00', '2022-02-11 00:00:00', '2022-03-08 00:00:00',
#  '2022-04-03 00:00:00', '2022-03-30 00:00:00', '2022-03-28 00:00:00',
#  '2022-03-18 00:00:00', '2022-03-14 00:00:00', '2022-04-06 00:00:00',
#  '2022-04-04 00:00:00', '2022-03-24 00:00:00', '2022-03-19 00:00:00',
#  '2022-03-09 00:00:00', '2022-03-25 00:00:00', '2022-03-02 00:00:00',
#  '2022-03-13 00:00:00', '2022-03-29 00:00:00', '2022-03-31 00:00:00',
#  '2022-03-17 00:00:00', '2022-03-07 00:00:00', '2022-03-15 00:00:00',
#  '2022-02-16 00:00:00', '2022-02-18 00:00:00', '2022-03-23 00:00:00',
# ...

# %%
#df["Day"] = pd.to_datetime(df["Date_of_Journey"],infer_datetime_format=True).dt.day
data["Day"] = pd.to_datetime(data["Order_Date"],format='%d-%m-%Y').dt.day

# %%
data.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# ...

# %%
data["Month"] = pd.to_datetime(data["Order_Date"],format='%d-%m-%Y').dt.month
data["Year"] = pd.to_datetime(data["Order_Date"],format='%d-%m-%Y').dt.year

# %%
data[["Order_Date"]].head()
# Out:
#   Order_Date
# 0 2022-02-12
# 1 2022-02-13
# 2 2022-03-04
# 3 2022-02-13
# 4 2022-02-14

# %%
data.drop("Order_Date",axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# 2                    74.006619                   4                     3
#
#    Vehicle_condition  Type_of_vehicle  ...  Month_Ordered  Year_Ordered  \
# 0                  2                1  ...              2          2022
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42646 entries, 0 to 42645
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          42646 non-null  float64
#  1   Delivery_person_Ratings      41359 non-null  float64
#  2   Restaurant_latitude          42646 non-null  float64
#  3   Restaurant_longitude         42646 non-null  float64
#  4   Delivery_location_latitude   42646 non-null  float64
#  5   Delivery_location_longitude  42646 non-null  float64
#  6   Weather_conditions           42646 non-null  int64
#  7   Road_traffic_density         42646 non-null  int64
#  8   Vehicle_condition            42646 non-null  int64
#  9   Type_of_vehicle              42646 non-null  int64
#  10  multiple_deliveries          42646 non-null  float64
#  11  City                         42646 non-null  int64
#  12  Time_taken(min)              42646 non-null  int64
# ...

# %%
data.rename(columns={"Day": "Day_Ordered", "Month": "Month_Ordered", "Year": "Year_Ordered", "Time_taken (min)":"Time_taken_min"}, inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes', 'Day_Ordered', 'Month_Ordered', 'Year_Ordered'],
#       dtype='object')

# %% [markdown]
# ### Segregating Numerical and Categorical columns

# %%
print(data.head())
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
# 3                 34.0                      4.3            30.899584
# 4                 24.0                      4.7            26.463504
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
# 3             75.809346                   30.919584
# 4             80.372929                   26.593504
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                   1                     1
# 1                    76.347589                   5                     2
# ...

# %%
import pandas as pd

def column_segregator(data):
    """This function segregates columns into categorical and numerical columns."""
    # Select categorical columns
    categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
    
    # Select numerical columns
    numerical_columns = data.select_dtypes(exclude=['object']).columns.tolist()

    return categorical_columns, numerical_columns

# Assuming 'data' is your DataFrame
categorical_columns, numerical_columns = column_segregator(data)

# Output the result
print("Categorical Columns:", categorical_columns)
print("Numerical Columns:", numerical_columns)
# Out:
# Categorical Columns: []
# Numerical Columns: ['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle', 'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered', 'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet', 'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack', 'Festival_Yes', 'Day_Ordered', 'Month_Ordered', 'Year_Ordered']

# %%
# Check the categorical columns list
print("Categorical Columns:", categorical_columns)

# Now try to describe the categorical columns
if categorical_columns:
    print(data[categorical_columns].describe())
else:
    print("No categorical columns to describe.")
# Out:
# Categorical Columns: []
# No categorical columns to describe.

# %% [markdown]
# Above freq (frequency) refers to the most occcuring value's total instances.

# %%
# Check if categorical columns exist in the DataFrame
missing_columns = [col for col in categorical_columns if col not in data.columns]
if missing_columns:
    print("Missing columns:", missing_columns)
else:
    print("All categorical columns are present in the DataFrame.")
# Out:
# All categorical columns are present in the DataFrame.

# %%
data[numerical_columns].describe().T
# Out:
#                                count         mean        std          min  \
# Delivery_person_Age          42646.0    29.609152   5.680654    20.000000
# Delivery_person_Ratings      41359.0     4.633202   0.315887     2.500000
# Restaurant_latitude          42646.0    17.148937   7.942409   -30.905562
# Restaurant_longitude         42646.0    70.607475  21.678405   -88.352885
# Delivery_location_latitude   42646.0    17.479846   7.339848     0.010000
# Delivery_location_longitude  42646.0    70.836267  21.134100     0.010000
# Weather_conditions           42646.0     3.471111   1.706360     1.000000
# Road_traffic_density         42646.0     2.603245   1.245735     1.000000
# Vehicle_condition            42646.0     0.996037   0.817707     0.000000
# Type_of_vehicle              42646.0     1.493270   0.641028     1.000000
# multiple_deliveries          42646.0     0.749050   0.572360     0.000000
# City                         42646.0     2.223046   0.425376     1.000000
# ...

# %% [markdown]
# As we can see the difference between descriptive stats of both numerical and categorical columns.

# %%
for column in categorical_columns:
    if data[column].str.isnumeric().any():
        print("Numeric values found in categorical column:", column)
    else:
        print("No numeric values found in categorical column:", column)

# %%
## Filter rows that don't contain ":" (i.e., rows with floating-point values)
#filtered_rows = data[data["Time_Orderd"].apply(lambda x: pd.notnull(x) and ":" not in str(x))]
#
## Sort rows based on "Time_Orderd" column
#sorted_rows = filtered_rows.sort_values(by="Time_Orderd")
#
## Retrieve only the "Time_Orderd" column values
#result = pd.DataFrame(sorted_rows["Time_Orderd"])
#
## Count the occurrences of each unique value in the resulting column
#value_counts = result["Time_Orderd"].value_counts()
#
## Display the value counts
#print(value_counts,"\nSum =",value_counts.sum())

# %%
## Filter rows that don't contain ":" (i.e., rows with floating-point values)
## Filter rows that don't contain ":" (i.e., rows with floating-point values)
#filtered_rows = data[data["Time_Order_picked"].apply(lambda x: pd.notnull(x) and ":" not in str(x))]
#
## Sort rows based on "Time_Orderd" column
#sorted_rows = filtered_rows.sort_values(by="Time_Order_picked")
#
## Retrieve only the "Time_Orderd" column values
#result = pd.DataFrame(sorted_rows["Time_Order_picked"])
#
## Count the occurrences of each unique value in the resulting column
#value_counts = result["Time_Order_picked"].value_counts()
#
## Display the value counts
#print(value_counts,"\nSum =",value_counts.sum())
##data.drop(filtered_rows.index, axis=0, inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame and correlation_matrix is calculated
correlation_matrix = data.corr(numeric_only=True)

# Set up the figure size
plt.figure(figsize=(12, 10))  # Adjust the figure size as per your data

# Set font scale for better readability of annotations
sns.set(font_scale=1.2)

# Create the heatmap with annotations, color map, and line widths
sns.heatmap(
    correlation_matrix, 
    annot=True,                  # Show correlation coefficients inside the heatmap
    cmap="coolwarm",             # Color palette to use
    linewidths=0.6,              # Width of the lines separating cells
    fmt=".2f",                   # Format annotations with two decimal places
    annot_kws={"size": 9},      # Increase the font size of annotations
    cbar_kws={"shrink": 0.8},    # Shrink color bar to fit better
    xticklabels=correlation_matrix.columns,  # Set custom x-tick labels (correlation matrix columns)
    yticklabels=correlation_matrix.columns,  # Set custom y-tick labels (correlation matrix rows)
)

# Rotate x and y axis labels for better readability
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels 45 degrees and align right
plt.yticks(rotation=0)  # Keep y-axis labels horizontal

# Set title for the heatmap
plt.title("Correlation Heatmap", fontsize=16)

# Adjust layout to ensure labels aren't cut off
plt.tight_layout()

# Show the plot
plt.show()

# %%
categorical_columns
# Out:
# []

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes', 'Day_Ordered', 'Month_Ordered', 'Year_Ordered'],
#       dtype='object')

# %% [markdown]
# ## Ordinal Encoding:

# %%
def barplot_func(data,input_feature,output_feature):
    plt.figure(figsize=(10, 11))
    sns.barplot(data=data,x=data[input_feature],y=data[output_feature], errorbar="sd")  # Adding error bars based on standard deviation
    plt.xlabel(f'{input_feature}')
    plt.ylabel(f'{output_feature}')
    plt.title(f'{output_feature} by {input_feature}')
    plt.xticks(rotation=90)
    print('\n')
    plt.show()

# %%
barplot_func(data,"Weather_conditions","Time_taken(min)")

# %%
data["Weather_conditions"].unique()
# Out:
# array([1, 5, 4, 3, 2, 6], dtype=int64)

# %%
Weather_conditions_map = {'Fog':1,'Cloudy':2,'Windy':3,'Sandstorms':4,'Stormy':5,'Sunny':6} #(Least likely to cause delays)

# %%
data["Road_traffic_density"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
Road_traffic_density_map = {'Jam':1, 'High':2, 'Medium':3, 'Low':4}

# %%
barplot_func(data,"Type_of_vehicle","Time_taken(min)")

# %%
data["Type_of_vehicle"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
Type_of_vehicle_map = {'motorcycle':1, 'scooter':2, 'electric_scooter':3}

# %%
barplot_func(data,"City","Time_taken(min)")

# %%
data["City"].unique()
# Out:
# array([2, 3, 1], dtype=int64)

# %%
City_map = {'Urban':3, 'Metropolitian':2, 'Semi-Urban':1}

# %%
# Define your mapping dictionaries
mapping_dicts = {
    'City': City_map,
    'Type_of_vehicle': Type_of_vehicle_map,
    "Road_traffic_density" : Road_traffic_density_map,
    "Weather_conditions" : Weather_conditions_map
}

# %%
list(mapping_dicts.keys())
# Out:
# ['City', 'Type_of_vehicle', 'Road_traffic_density', 'Weather_conditions']

# %%
#data["clarity"] = data["clarity"].map(clarity_map)
# Map values using the mapping dictionaries
for column in list(mapping_dicts.keys()) :
    data[column] = data[column].map(mapping_dicts[column])

# %% [markdown]
# ## One Hot Encoding:

# %%
def one_hot_encoder_func(data, column_name):
    """
    Perform one-hot encoding for a categorical column in a DataFrame.

    Parameters:
        data (DataFrame): The input DataFrame containing the data to be encoded.
        column_name (str): The name of the categorical column to be one-hot encoded.

    Returns:
        DataFrame: The input DataFrame with one-hot encoded columns added and the original column dropped.
    """
    # Validate inputs
    if not isinstance(data, pd.DataFrame):
        raise ValueError("Input 'data' must be a pandas DataFrame.")
    
    if column_name not in data.columns:
        raise ValueError(f"Column '{column_name}' not found in the DataFrame.")

    # Perform one-hot encoding
    one_hot_encoded = pd.get_dummies(data[column_name], prefix=column_name, dtype=int)

    # Concatenate the one-hot encoded columns with the original dataframe
    data = pd.concat([data, one_hot_encoded], axis=1)

    # Drop the original column
    data.drop(column_name, axis=1, inplace=True)

    return data

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                 NaN                   NaN
# 1                    76.347589                 NaN                   NaN
# 2                    74.006619                 NaN                   NaN
#
#    Vehicle_condition  Type_of_vehicle  ...  Month_Ordered  Year_Ordered  \
# 0                  2              NaN  ...              2          2022
# ...

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet',
#        'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack',
#        'Festival_Yes', 'Day_Ordered', 'Month_Ordered', 'Year_Ordered'],
#       dtype='object')

# %%
data['Type_of_order_Buffet'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data = one_hot_encoder_func(data,"Type_of_order_Buffet")

# %%
data = one_hot_encoder_func(data,"Festival_Yes")

# %%
data.head(3)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                 36.0                      4.2            30.327968
# 1                 21.0                      4.7            10.003064
# 2                 23.0                      4.7            18.562450
#
#    Restaurant_longitude  Delivery_location_latitude  \
# 0             78.046106                   30.397968
# 1             76.307589                   10.043064
# 2             73.916619                   18.652450
#
#    Delivery_location_longitude  Weather_conditions  Road_traffic_density  \
# 0                    78.116106                 NaN                   NaN
# 1                    76.347589                 NaN                   NaN
# 2                    74.006619                 NaN                   NaN
#
#    Vehicle_condition  Type_of_vehicle  ...  Type_of_order_Drinks  \
# 0                  2              NaN  ...                     0
# ...

# %% [markdown]
# # Visualizing + Deriving Insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def lineplot_with_kde(input_feature, output_feature, data):
    """This function will plot a line plot with KDE curve based on given arguments."""
    plt.figure(figsize=(10, 6))
    sns.lineplot(x=data[input_feature], y=data[output_feature], color='blue', label='Line Plot')
    sns.kdeplot(data[input_feature], data[output_feature], cmap='Reds', label='KDE', shade=True)
    plt.title(f"Line Plot with KDE of {output_feature} based on {input_feature}")
    plt.xlabel(f"{input_feature}")
    plt.ylabel(f"{output_feature}")
    plt.legend()
    plt.show()

# %%
target_col = "Time_taken(min)"

# %%
barplot_func(data,"Delivery_person_Age",target_col)

# %% [markdown]
# We can say as the age is rising it takes more time for delivery.

# %%
barplot_func(data,"Delivery_person_Ratings",target_col)

# %% [markdown]
# As we can see the highest rating delivery persons has less delivery time as compared to low rated delivery persons.

# %%
barplot_func(data,"Weather_conditions",target_col)

# %%
Weather_conditions_map
# Out:
# {'Fog': 1, 'Cloudy': 2, 'Windy': 3, 'Sandstorms': 4, 'Stormy': 5, 'Sunny': 6}

# %%
barplot_func(data,"Vehicle_condition",target_col)

# %%
# Assuming 'data' is your DataFrame
correlation_matrix = data.corr(numeric_only=True)

## Set up the figure and axes
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.2)  # Adjust the font size for annotations

## Create the heatmap with annotations and a color map
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")

## Add a title
plt.title("Correlation Heatmap")

## Show the plot
plt.show()

# %% [markdown]
# As we can see there is no correlation between 'Type_of_order' and 'Time_taken(min)' and there is no difference through barplot too, so we drop 'Type_of_order' column

# %%
barplot_func(data,"multiple_deliveries",target_col)

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Drinks',
#        'Type_of_order_Meal', 'Type_of_order_Snack', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet_0',
#        'Type_of_order_Buffet_1', 'Festival_Yes_0', 'Festival_Yes_1'],
#       dtype='object')

# %% [markdown]
# They have a positive correralation.

# %%
# Updated barplot function with correct column reference
barplot_func(data, "Festival_Yes_1", "Time_taken(min)")

# %%
# Check for NaN values in both columns
print(data["City"].isnull().sum())  # NaN values in City
print(data["Time_taken(min)"].isnull().sum())  # NaN values in Time_taken(min)

# If any missing values, you might want to drop or fill them
data = data.dropna(subset=["City", "Time_taken(min)"])  # Drop rows with NaNs
# Out:
# 0
# 0

# %%
# Check how many rows are left after dropping
print(f"Rows after dropping missing 'City': {data.shape[0]}")
# Out:
# Rows after dropping missing 'City': 0

# %%
# Create the barplot after dropping missing 'City' values
barplot_func(data, "City", "Time_taken(min)")

# %%
# Try a boxplot to check the distribution of 'Time_taken(min)' for each city
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x="City", y="Time_taken(min)")
plt.xticks(rotation=45)
plt.title('Time Taken (min) for each City')
plt.show()

# %% [markdown]
# When there is a festival going on the order becomes significantly late.

# %%
City_map
# Out:
# {'Urban': 3, 'Metropolitian': 2, 'Semi-Urban': 1}

# %% [markdown]
# As we can see semi urban cities have more impact then metropolitian and semi-urban cities are least to increase deliery time.

# %%
barplot_func(data,"Delivery_person_Ratings","Delivery_person_Age")

# %% [markdown]
# - 23-25 : 2.5-2.9<br>
# - 33-35 : 3.0<br>
# - 25-27 : 3.1-3.4<br>
# - 30-33 : 3.5-3.9<br>
# - 30-32 : 4.0-4.4<br>
# - 28-30 : 4.5-5.0<br>

# %%
barplot_func(data,"multiple_deliveries","Delivery_person_Age")

# %% [markdown]
# As we can see 28-30 age group people has no mutliple deliveries due another thing to note is that this age group is the same people who are getting ratings between 4.5-5.0

# %%
barplot_func(data,"multiple_deliveries","Delivery_person_Ratings")

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Drinks',
#        'Type_of_order_Meal', 'Type_of_order_Snack', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet_0',
#        'Type_of_order_Buffet_1', 'Festival_Yes_0', 'Festival_Yes_1'],
#       dtype='object')

# %%
# Check for missing values in the columns
print(data["multiple_deliveries"].isnull().sum())
print(data["Road_traffic_density"].isnull().sum())

# Ensure there are no missing values, or drop them if necessary
data = data.dropna(subset=["multiple_deliveries", "Road_traffic_density"])
# Out:
# 0
# 0

# %%
barplot_func(data,"multiple_deliveries","Road_traffic_density")

# %%
Road_traffic_density_map
# Out:
# {'Jam': 1, 'High': 2, 'Medium': 3, 'Low': 4}

# %% [markdown]
# Through above visualization we can assume that as the traffic is increasing we are seeing a decrease in multiple_deliveries.

# %%
barplot_func(data, "multiple_deliveries", "Road_traffic_density")

# %% [markdown]
# Festival causes an increase in road traffic density

# %%
barplot_func(data,"City","Road_traffic_density")

# %%
City_map
# Out:
# {'Urban': 3, 'Metropolitian': 2, 'Semi-Urban': 1}

# %% [markdown]
# Road Traffic Density is lowest in urban and highest in semi-urban.

# %%
barplot_func(data,"Type_of_vehicle","Vehicle_condition")

# %%
Type_of_vehicle_map
# Out:
# {'motorcycle': 1, 'scooter': 2, 'electric_scooter': 3}

# %% [markdown]
# We can say electric_scooter i.e. (3) is in most good condition.

# %%
barplot_func(data,"Festival_Yes_1","multiple_deliveries")

# %% [markdown]
# This shows that when there is festival there is increase in multiple deliveries.

# %%
print(data.columns)
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Drinks',
#        'Type_of_order_Meal', 'Type_of_order_Snack', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet_0',
#        'Type_of_order_Buffet_1', 'Festival_Yes_0', 'Festival_Yes_1'],
#       dtype='object')

# %% [markdown]
# Dropping Festival_No as it will be showcased by Festival_Yes through zeros

# %%
def custom_pairbarplot(data, columns_to_compare, input_column_type, output_column,type_of_plot):

    # Grouping and summing each order type based on festival status
    grouped = data.groupby(output_column)[columns_to_compare].sum()

    # Plotting the bar plots
    ax = grouped.plot(kind=type_of_plot, figsize=(10, 4))
    ax.set_xlabel(f"{output_column} Status")
    ax.set_ylabel('Sum Count')
    ax.set_title(f'Comparison of {input_column_type} for {output_column} Status')

    plt.xticks(rotation=0)
    plt.legend(title=f"{output_column} Status")
    plt.show()

# %%
print(data.columns)  # Check if 'Type_of_order_Buffet' exists
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Drinks',
#        'Type_of_order_Meal', 'Type_of_order_Snack', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet_0',
#        'Type_of_order_Buffet_1', 'Festival_Yes_0', 'Festival_Yes_1'],
#       dtype='object')

# %%
print(data.columns)  # Verify the column names
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_vehicle',
#        'multiple_deliveries', 'City', 'Time_taken(min)', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Drinks',
#        'Type_of_order_Meal', 'Type_of_order_Snack', 'Day_Ordered',
#        'Month_Ordered', 'Year_Ordered', 'Type_of_order_Buffet_0',
#        'Type_of_order_Buffet_1', 'Festival_Yes_0', 'Festival_Yes_1'],
#       dtype='object')

# %%
print(data['City'].unique())
# Out:
# []

# %%
print(data['City'].isnull().sum())  # Should be 0
# Out:
# 0

# %%
data = data.dropna(subset=['City'])  # Drop rows with NaN values in 'City'

# %%
print(data[['Type_of_order_Buffet_0', 'Type_of_order_Buffet_1', 'Type_of_order_Meal', 'Type_of_order_Drinks']].head())
# Out:
# Empty DataFrame
# Columns: [Type_of_order_Buffet_0, Type_of_order_Buffet_1, Type_of_order_Meal, Type_of_order_Drinks]
# Index: []

# %%
print(data.shape)
# Out:
# (0, 26)

# %%
print(data['City'].notnull().sum())  # This should be a positive integer
# Out:
# 0

# %%
print(data.head())  # Print the first 5 rows of the dataset
# Out:
# Empty DataFrame
# Columns: [Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_vehicle, multiple_deliveries, City, Time_taken(min), Day_Ordered, Month_Ordered, Year_Ordered, Type_of_order_Drinks, Type_of_order_Meal, Type_of_order_Snack, Day_Ordered, Month_Ordered, Year_Ordered, Type_of_order_Buffet_0, Type_of_order_Buffet_1, Festival_Yes_0, Festival_Yes_1]
# Index: []
#
# [0 rows x 26 columns]

# %%
print(data['City'].notnull().sum())  # Count of non-null values in 'City'
print(data['Time_taken(min)'].notnull().sum())  # Count of non-null values in 'Time_taken(min)'
# Out:
# 0
# 0

# %%
print(data.isnull().sum())  # Check missing data in all columns
# Out:
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_vehicle                0
# multiple_deliveries            0
# City                           0
# Time_taken(min)                0
# Day_Ordered                    0
# Month_Ordered                  0
# Year_Ordered                   0
# Type_of_order_Drinks           0
# Type_of_order_Meal             0
# Type_of_order_Snack            0
# Day_Ordered                    0
# Month_Ordered                  0
# Year_Ordered                   0
# Type_of_order_Buffet_0         0
# Type_of_order_Buffet_1         0
# Festival_Yes_0                 0
# Festival_Yes_1                 0
# dtype: int64

# %%
data = pd.read_csv(r"D:\Final_year\Final_year_MCA_project\Food_Delivery_Time_Prediction-AZURE\notebooks\cleaned_data.csv")
print(data.shape)
# Out:
# (42646, 21)

# %%
# Count non-null values before dropping NaNs
print("Before dropna():")
print(data['City'].notnull().sum(), "non-null values in 'City'")

# Apply dropna and check the size
data_cleaned = data.dropna(subset=["City", "Time_taken(min)"])
print("After dropna():")
print(data_cleaned.shape)  # Check the new shape of the data

# If the DataFrame is empty, decide whether to fill missing values instead:
data_filled = data.fillna({"City": "Unknown", "Time_taken(min)": 0})
print(data_filled.shape)
# Out:
# Before dropna():
# 42646 non-null values in 'City'
# After dropna():
# (42646, 21)
# (42646, 21)

# %%
City_map
# Out:
# {'Urban': 3, 'Metropolitian': 2, 'Semi-Urban': 1}

# %%
columns_to_compare = ['Type_of_order_Buffet', 'Type_of_order_Drinks', 'Type_of_order_Meal', 'Type_of_order_Snack']
input_column_type = 'Order_Type'   # Update to reflect the actual x-axis label you want
output_column = 'Festival_Yes'
type_of_plot = 'bar'

custom_pairbarplot(data, columns_to_compare, input_column_type, output_column, type_of_plot)

# %%
# Assuming 'data' is your DataFrame
correlation_matrix = data.corr()

## Set up the figure and axes
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.2)  # Adjust the font size for annotations

## Create the heatmap with annotations and a color map
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5, fmt=".2f")

## Add a title
plt.title("Correlation Heatmap")

## Show the plot
plt.show()

# %%
data["City"].unique()
# Out:
# array([2, 3, 1], dtype=int64)

# %%
# Save the dataframe as a CSV file
data.to_csv('cleaned_data.csv', index=False)
